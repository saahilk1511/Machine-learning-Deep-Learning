# %%
import tensorflow as tf
import pandas as pd
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
from tensorflow.keras.datasets import reuters
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
number_of_features = 5000
data = reuters.load_data(num_words = number_of_features)
(X_train, y_train) , (X_test, y_test)= data
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/datasets/reuters.py:143: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/datasets/reuters.py:144: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
# Data encoding
tokenizer = Tokenizer(num_words=number_of_features)
features_train = tokenizer.sequences_to_matrix(X_train, mode='binary' )
features_test  = tokenizer.sequences_to_matrix(X_test, mode='binary')

# %%
# One-hot encoding
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# ### Question 1: Build an MLP (only MLP structure) deep neural network to classify Reuters news-wire data into 46 different categories
# #### Question 5: Add checkpoints and early stopping

# %%
## MLP structure

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(monitor='val_loss',mode = "min", patience=3, verbose=1)

model_checkpoints = ModelCheckpoint("HW6_Khanna.h5", 
                                    save_best_only=True, monitor='val_loss', mode='min', save_freq='epoch')

# %%
tf.random.set_seed(64)

def best_model(best_para):

    model = Sequential()
    model.add(Dense(best_para["neurons1"], activation='relu')) # Layer 1
    model.add(Dropout(0.5))

    model.add(Dense(best_para["neurons2"], activation='relu')) # Layer 2
    model.add(Dropout(0.5))

    model.add(Dense(46, activation='softmax')) # Output layer

    model.compile(loss='categorical_crossentropy',
                  optimizer= best_para["optimizer"],
                  metrics=['accuracy']) 

    model.fit(features_train, Y_train, epochs=best_para["epochs"], batch_size=300, validation_data=(features_test, Y_test), 
              callbacks=[early_stop, model_checkpoints])
    
    return model

# %% [markdown]
# ### Question 1: Exploratory data analysis

# %%
# statistics over all 46 classes

import collections
import statistics

labels = ['cocoa','grain','veg-oil','earn','acq','wheat','copper','housing','money-supply',
           'coffee','sugar','trade','reserves','ship','cotton','carcass','crude','nat-gas',
           'cpi','money-fx','interest','gnp','meal-feed','alum','oilseed','gold','tin',
           'strategic-metal','livestock','retail','ipi','iron-steel','rubber','heat','jobs',
           'lei','bop','zinc','orange','pet-chem','dlr','gas','silver','wpi','hog','lead']

train_doc_count = collections.Counter(y_train)
test_doc_count = collections.Counter(y_test)
mean_words_train = [statistics.mean([len(e) for e in X_train[y_train.flatten() == i]]) for i in range(46)]
mean_words_test = [statistics.mean([len(e) for e in X_test[y_test.flatten() == i]]) for i in range(46)]

# %%
train_temp = []
for i,j in sorted(train_doc_count.items()):
    train_temp.append(j)

test_temp = []
for i,j in sorted(test_doc_count.items()):
    test_temp.append(j)
    
df = pd.DataFrame()

# %%
df["Class"] = labels 
df["train_doc_count"] = train_temp # of documents in train set
df["test_doc_count"] = test_temp # of documents in test set
df["mean_words_train"] = mean_words_train # Mean # of words in train set
df["mean_words_test"] = mean_words_test # Mean # of words in test set

# %%
df
# Out:
#               Class  train_doc_count  test_doc_count  mean_words_train  \
# 0             cocoa               55              12        225.781818
# 1             grain              432             105        188.668981
# 2           veg-oil               74              20        184.864865
# 3              earn             3159             813         87.671415
# 4               acq             1949             474        135.825038
# 5             wheat               17               5        213.352941
# 6            copper               48              14        154.458333
# 7           housing               16               3        180.375000
# 8      money-supply              139              38        191.482014
# 9            coffee              101              25        225.871287
# 10            sugar              124              30        184.725806
# 11            trade              390              83        253.797436
# 12         reserves               49              13        186.918367
# 13             ship              172              37        164.656977
# 14           cotton               26               2        142.692308
# 15          carcass               20               9        170.450000
# 16            crude              444              99        219.786036
# 17          nat-gas               39              12        149.820513
# 18              cpi               66              20        146.848485
# 19         money-fx              549             133        185.342441
# 20         interest              269              70        201.000000
# 21              gnp              100              27        281.830000
# 22        meal-feed               15               7        183.733333
# 23             alum               41              12        157.341463
# 24          oilseed               62              19        151.241935
# 25             gold               92              31        152.380435
# 26              tin               24               8        259.875000
# 27  strategic-metal               15               4        145.266667
# 28        livestock               48              10        177.479167
# 29           retail               19               4        258.315789
# 30              ipi               45              12        175.777778
# 31       iron-steel               39              13        157.512821
# 32           rubber               32              10        207.437500
# 33             heat               11               5        115.545455
# 34             jobs               50               7        152.940000
# 35              lei               10               6        142.300000
# 36              bop               49              11        228.448980
# 37             zinc               19               2        164.736842
# 38           orange               19               3        130.210526
# 39         pet-chem               24               5        153.958333
# 40              dlr               36              10        278.388889
# 41              gas               30               8        175.066667
# 42           silver               13               3        197.923077
# 43              wpi               21               6        152.714286
# 44              hog               12               5         90.750000
# 45             lead               18               1        159.888889
#
#     mean_words_test
# 0        250.166667
# 1        187.428571
# 2        150.850000
# 3         84.356704
# 4        137.546414
# 5        103.600000
# 6        149.428571
# 7         91.000000
# 8        186.947368
# 9        168.040000
# 10       179.766667
# 11       265.265060
# 12       167.076923
# 13       171.594595
# 14       148.500000
# 15       235.444444
# 16       233.272727
# 17       209.000000
# 18       217.300000
# 19       239.112782
# 20       212.657143
# 21       283.185185
# 22       132.000000
# 23       126.083333
# 24       130.421053
# 25       182.258065
# 26       302.000000
# 27       141.750000
# 28       145.300000
# 29       149.750000
# 30       186.750000
# 31       139.000000
# 32       257.100000
# 33        73.200000
# 34       247.285714
# 35       149.833333
# 36       242.818182
# 37       138.500000
# 38        89.666667
# 39       188.400000
# 40       210.300000
# 41       129.375000
# 42       253.000000
# 43       190.166667
# 44       158.800000
# 45       146.000000

# %%
plt.figure(figsize=(11,7))
sns.distplot(df["mean_words_train"], label="Train Set")
sns.distplot(df["mean_words_test"], label="Test Set")
plt.xlabel("# of words")
plt.legend()
plt.title("Distribution of Mean # of words")
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,7))
sns.jointplot(x = 'mean_words_test', y = 'mean_words_train', data = df, kind = 'kde')
plt.title("Mean Words", loc="left")

sns.jointplot(x = 'train_doc_count', y = 'test_doc_count', data = df, kind = 'kde')
plt.title("# Document",loc="left")
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(range(1,47),df["train_doc_count"],color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10, label= "Train")
plt.plot(range(1,47),df["test_doc_count"],color='green', linestyle='-', marker='x',
         markerfacecolor='black', markersize=10, label= "Test")
plt.legend()
plt.title('# Documents in Train vs Test')
plt.xlabel('Class Index')
plt.ylabel('# Documents')
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# ### Question 2: Find the best setting of your neural network between the following options using grid search and random search, which gives you the best results based on the “test” data set by trying

# %%
tf.random.set_seed(64)
def create_model(optimizer, neurons1, neurons2):
    
    # create model
    model = Sequential()
    
    model.add(Dense(neurons1, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(neurons2, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(46, activation='softmax'))
    
    # Compile model
    model.compile(loss="categorical_crossentropy", 
                    optimizer=optimizer,  # OPTIMIZER
                    metrics=["accuracy"]) # Accuracy performance metric
    return model

# Create Hyperparameters 
epochs = [10, 50]
optimizer = ['rmsprop', 'adamax', 'nadam','adagrad']
neurons1 = [32, 100, 100, 200]
neurons2 = [32, 32, 100, 200]

model = KerasClassifier(build_fn=create_model, epochs=epochs, batch_size=300, verbose=0)

# Create hyperparameter options
param_grid = dict(optimizer=optimizer, neurons1=neurons1, neurons2=neurons2,epochs=epochs )

# %%
# Create grid search
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# Fit gird search
grid_result = grid.fit(features_test, Y_test) # Search results based on the “test” data 

# summarize results
print("Best: {} using {}".format(grid_result.best_score_, grid_result.best_params_))
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Init Plugin
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Init Graph Optimizer
# Init Kernel
# Init Plugin
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Init Graph Optimizer
# Init Kernel
# Metal device set to: Apple M1
# Metal device set to: Apple M1
# Metal device set to: Apple M1
# Metal device set to: Apple M1
# Metal device set to: Apple M1
# Metal device set to: Apple M1
# Metal device set to: Apple M1
# Metal device set to: Apple M1
# 2021-10-21 14:32:59.119494: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.119609: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.121532: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.121802: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.131032: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.131148: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.146002: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.146139: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.146863: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.147096: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.147919: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.148090: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.148557: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.148964: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.156793: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:32:59.156942: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:32:59.581196: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.582737: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:32:59.592107: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.595733: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:32:59.617440: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.618073: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:32:59.702175: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.702478: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.702709: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:32:59.702775: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:32:59.702946: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.703097: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:32:59.705472: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.705691: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:32:59.711728: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:32:59.717946: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:33:00.400705: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:00.458127: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:00.464015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:00.488059: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:00.668941: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:01.136366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:01.588257: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:02.143570: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:02.945820: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:03.495243: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:03.802258: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:05.692248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:05.737306: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:05.782454: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:06.224160: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:06.884722: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:07.833730: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:07.891615: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:08.373508: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:08.701042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:09.064058: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:09.833393: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:10.280348: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:10.634686: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:11.484347: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:11.652094: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:12.068175: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:12.165536: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:12.347656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:12.354252: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:12.537380: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:12.591806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:12.699709: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:13.194242: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:13.240537: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:13.350030: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.025104: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.060083: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.100091: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.147790: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.208546: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.268244: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.315824: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:15.478505: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:16.171817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:16.222892: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:16.371914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:16.578148: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:17.746189: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:18.051036: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:18.132195: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:18.562559: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:18.592956: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:18.699422: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:18.732462: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x16c8bcf70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:18.908775: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:19.376484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:19.640127: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:19.721934: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:19.821626: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:20.630289: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:21.421476: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:21.577518: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:21.592014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:21.607812: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:21.615491: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:21.650976: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x131e85ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:21.770636: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:22.114714: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:22.504653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:22.757141: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:22.953116: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:23.877309: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:24.667232: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x176154430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:24.974643: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x28c9d2700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:25.077577: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:25.120618: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:25.142949: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x29a2a40d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:25.531484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:25.541554: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x28cdea940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x17809a9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:26.231864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:26.416554: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:26.436657: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:26.464652: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:26.562599: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:27.189012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:28.145617: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:28.198528: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x14f4b3700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:28.909349: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:28.918084: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:28.942167: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x28ab15ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x17682b940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:29.070339: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x16e49ab80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:29.339070: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x16ddd89d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:30.293547: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x299390b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:30.456058: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:30.521105: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:30.751588: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:31.960215: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:31.988100: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x14f7729d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:32.337505: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:32.532870: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:32.533701: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:33.475878: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:34.573437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:35.421582: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:36.901463: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:36.982931: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:37.314008: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:37.414516: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:37.728441: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:37.786647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x17a3623a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:38.680065: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:39.056899: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:39.327625: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:41.699493: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:41.832408: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:41.947450: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x14f772f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-10-21 14:33:42.253227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:43.102994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:45.099036: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:45.572368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:45.783571: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:46.034823: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:46.099990: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:46.861893: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:47.007758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:47.250332: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:47.776605: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:47.995709: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:48.769100: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:48.812760: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:49.291290: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:50.360449: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:50.403221: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:50.496250: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:50.817125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:51.223061: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:51.236560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:51.386733: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:51.433746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:51.489039: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:51.982442: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:52.260349: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:52.348408: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:53.871194: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:53.892608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:53.902124: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:53.939758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:54.515961: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:54.599168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:54.679634: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:54.873613: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:55.026128: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:55.228914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:55.475953: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:55.555792: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:56.846005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:57.072487: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:57.098442: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:57.750964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:57.975042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:58.095933: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:58.202076: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:58.285087: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:58.456269: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:59.117925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:59.205644: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:33:59.271048: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:00.096894: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:00.312252: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:00.356265: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:00.431276: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:01.331210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:01.659321: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:01.838923: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:01.880599: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:01.880662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:02.381416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:02.745632: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:02.768830: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:02.797636: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:03.303367: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:03.341980: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:03.801653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:03.802606: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:04.975152: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:05.117994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:05.487770: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:34:05.679427: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# ...
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_45/dense_135/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_45/dense_135/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ResourceApplyAdaMax: CPU
# ReadVariableOp: GPU CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_45_dense_135_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adamax_adamax_update_resourceapplyadamax_m (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adamax_adamax_update_resourceapplyadamax_v (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_45/dense_135/MatMul/ReadVariableOp (ReadVariableOp)
#   Adamax/Adamax/update/ResourceApplyAdaMax (ResourceApplyAdaMax) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_45/dense_135/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_52666]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_47/dense_141/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_47/dense_141/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_47_dense_141_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_47/dense_141/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_47/dense_141/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_53756]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_48/dense_144/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_48/dense_144/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_48_dense_144_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_48/dense_144/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_48/dense_144/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_54406]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_53/dense_159/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_53/dense_159/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_53_dense_159_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_53/dense_159/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_53/dense_159/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_56046]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.56276345        nan 0.57345684        nan 0.57924173        nan
#  0.58725125        nan 0.59438374        nan 0.58637126        nan
#  0.62955421        nan 0.60239087        nan 0.63757503        nan
#  0.61797373        nan 0.64914721        nan 0.62821911        nan
#  0.67541216        nan 0.65404143        nan 0.67853457        nan
#  0.66829214        nan 0.63980675        nan 0.62287686        nan
#  0.63178418        nan 0.63979189        nan 0.66384059        nan
#  0.65938663        nan 0.6816528         nan 0.67185245        nan
#  0.67852863        nan 0.66517389        nan 0.66873719        nan
#  0.64958926        nan 0.70034677        nan 0.68520476        nan
#  0.70881142        nan 0.69589639        nan 0.6896623         nan
#  0.69099681        nan 0.68654704        nan 0.6852143         nan
#  0.71326536        nan 0.71860701        nan 0.72483933        nan
#  0.72083161        nan 0.72573475        nan 0.73329268        nan
#  0.72706928        nan 0.7230592         nan 0.75199972        nan
#  0.75556479        nan 0.7564501         nan 0.76179709        nan
#  0.72484231        nan 0.72884824        nan 0.72528438        nan
#  0.72483814        nan 0.75556658        nan 0.75155467        nan
#  0.76446853        nan 0.76224569        nan 0.74532654        nan
#  0.73285892        nan 0.74086605        nan 0.73508235        nan
#  0.75778639        nan 0.7591239         nan 0.76134849        nan
#  0.76179649        nan]
#   warnings.warn(
# Metal device set to: Apple M1
# 2021-10-21 14:37:37.017991: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-21 14:37:37.018145: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-21 14:37:37.187501: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-21 14:37:37.188771: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-10-21 14:37:37.418498: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Best: 0.7644685308138529 using {'epochs': 50, 'neurons1': 100, 'neurons2': 200, 'optimizer': 'rmsprop'}

# %%
from sklearn.model_selection import RandomizedSearchCV

rand = RandomizedSearchCV(estimator=model, param_distributions=param_grid, 
                            n_iter=4, n_jobs=-1) 


rand_output = rand.fit(features_test, Y_test) # Search results based on the “test” data 
print("Best: {} using {}".format(rand_output.best_score_, rand_output.best_params_))
# Out:
# 2021-10-21 14:37:42.086203: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:42.100540: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:42.105970: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:42.945598: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:42.955060: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:42.977937: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:43.032465: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:43.124107: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:46.384662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:46.416320: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:46.631803: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:50.793548: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:50.935503: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:54.202208: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:54.587811: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:55.722381: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:56.027614: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:56.154917: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:56.211743: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-10-21 14:37:56.304204: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# /opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_54/dense_162/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_54/dense_162/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_54_dense_162_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_54/dense_162/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_54/dense_162/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_56696]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_47/dense_141/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_47/dense_141/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_47_dense_141_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_47/dense_141/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_47/dense_141/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_53556]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_49/dense_147/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_49/dense_147/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_49_dense_147_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_49/dense_147/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_49/dense_147/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_55056]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_40/dense_120/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_40/dense_120/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_40_dense_120_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_40/dense_120/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_40/dense_120/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_48381]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_52/dense_156/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_52/dense_156/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_52_dense_156_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_52/dense_156/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_52/dense_156/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_57776]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_51/dense_153/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_51/dense_153/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_51_dense_153_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_51/dense_153/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_51/dense_153/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_56864]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_52/dense_156/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_52/dense_156/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_52_dense_156_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_52/dense_156/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_52/dense_156/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_57514]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_53/dense_159/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_53/dense_159/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_53_dense_159_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_53/dense_159/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_53/dense_159/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_58164]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_50/dense_150/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_50/dense_150/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_50_dense_150_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_50/dense_150/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_50/dense_150/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_56522]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 220, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py", line 1183, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py", line 950, in _call
#     return self._stateless_fn(*args, **kwds)
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 3023, in __call__
#     return graph_function._call_flat(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 1960, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/function.py", line 591, in call
#     outputs = execute.execute(
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Cannot assign a device for operation sequential_43/dense_129/MatMul/ReadVariableOp: Could not satisfy explicit device specification '' because the node {{colocation_node sequential_43/dense_129/MatMul/ReadVariableOp}} was colocated with a group of nodes that required incompatible device '/job:localhost/replica:0/task:0/device:GPU:0'. All available devices [/job:localhost/replica:0/task:0/device:CPU:0, /job:localhost/replica:0/task:0/device:GPU:0].
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=2 requested_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' assigned_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' resource_device_name_='/job:localhost/replica:0/task:0/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# ReadVariableOp: GPU CPU
# ResourceApplyAdagradV2: CPU
# _Arg: GPU CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   sequential_43_dense_129_matmul_readvariableop_resource (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   adagrad_adagrad_update_resourceapplyadagradv2_accum (_Arg)  framework assigned device=/job:localhost/replica:0/task:0/device:GPU:0
#   sequential_43/dense_129/MatMul/ReadVariableOp (ReadVariableOp)
#   Adagrad/Adagrad/update/ResourceApplyAdagradV2 (ResourceApplyAdagradV2) /job:localhost/replica:0/task:0/device:GPU:0
#
# 	 [[{{node sequential_43/dense_129/MatMul/ReadVariableOp}}]] [Op:__inference_train_function_51347]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/tfd/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.77649    0.64558479        nan]
#   warnings.warn(
# 2021-10-21 14:37:56.733858: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Best: 0.7764899969100952 using {'optimizer': 'nadam', 'neurons2': 200, 'neurons1': 100, 'epochs': 50}

# %% [markdown]
# ### Question 3: Find the best MLP with two hidden layers neural network that gives you the best performance. There is no limit on your choices, except the structure and number of hidden layers.
# Bonus: The best performance will get an extra 20 points.

# %%
if grid_result.best_score_ > rand_output.best_score_:
    print("Grid Search gave best parameters")
    best_para = grid_result.best_params_
else:
    print("Random Search gave best parameters")
    best_para = rand_output.best_params_
# Out:
# Random Search gave best parameters

# %%
best_para
# Out:
# {'optimizer': 'nadam', 'neurons2': 200, 'neurons1': 100, 'epochs': 50}

# %%
mlp = best_model(best_para)
losses = pd.DataFrame(mlp.history.history)
# Out:
# Epoch 1/50
#  5/30 [====>.........................] - ETA: 0s - loss: 3.7824 - accuracy: 0.0640
# 2021-10-21 14:39:19.895016: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 30/30 [==============================] - 1s 24ms/step - loss: 2.7747 - accuracy: 0.3848 - val_loss: 1.6991 - val_accuracy: 0.5917
# Epoch 2/50
#  5/30 [====>.........................] - ETA: 0s - loss: 1.7998 - accuracy: 0.5627
# 2021-10-21 14:39:20.630615: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 30/30 [==============================] - 0s 14ms/step - loss: 1.5907 - accuracy: 0.6248 - val_loss: 1.3656 - val_accuracy: 0.6866
# Epoch 3/50
# 30/30 [==============================] - 0s 14ms/step - loss: 1.2950 - accuracy: 0.7059 - val_loss: 1.2120 - val_accuracy: 0.7146
# Epoch 4/50
# 30/30 [==============================] - 0s 14ms/step - loss: 1.1065 - accuracy: 0.7405 - val_loss: 1.1159 - val_accuracy: 0.7395
# Epoch 5/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.9765 - accuracy: 0.7703 - val_loss: 1.0515 - val_accuracy: 0.7582
# Epoch 6/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.8448 - accuracy: 0.7940 - val_loss: 1.0072 - val_accuracy: 0.7680
# Epoch 7/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.7545 - accuracy: 0.8175 - val_loss: 0.9778 - val_accuracy: 0.7752
# Epoch 8/50
# 30/30 [==============================] - 0s 15ms/step - loss: 0.6749 - accuracy: 0.8313 - val_loss: 0.9658 - val_accuracy: 0.7841
# Epoch 9/50
# 30/30 [==============================] - 0s 15ms/step - loss: 0.6014 - accuracy: 0.8476 - val_loss: 0.9510 - val_accuracy: 0.7921
# Epoch 10/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5464 - accuracy: 0.8608 - val_loss: 0.9525 - val_accuracy: 0.7912
# Epoch 11/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4944 - accuracy: 0.8686 - val_loss: 0.9567 - val_accuracy: 0.7952
# Epoch 12/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.4503 - accuracy: 0.8830 - val_loss: 0.9666 - val_accuracy: 0.8001
# Epoch 00012: early stopping

# %% [markdown]
# ### Question 4: Plot training and test set results for the best model.

# %%
losses[['loss','val_loss']].plot(figsize=(15,7), 
                                 title="Train_Loss vs Test_Loss", 
                                 xlabel="Epochs",
                                 ylabel="Error_Rate")
# Out:
# <AxesSubplot:title={'center':'Train_Loss vs Test_Loss'}, xlabel='Epochs', ylabel='Error_Rate'>

# %%
losses[['accuracy','val_accuracy']].plot(figsize=(15,7), 
                                         title="Train_Accuracy vs Test_Accuracy", 
                                         xlabel="Epochs",
                                        ylabel="Accuracy_Score")
# Out:
# <AxesSubplot:title={'center':'Train_Accuracy vs Test_Accuracy'}, xlabel='Epochs', ylabel='Accuracy_Score'>
